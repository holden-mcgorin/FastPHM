# %% [markdown]
# # 示例：输出轴承运行阶段划分图
# - 主要分为正常阶段与退化阶段，少数研究额外增加失效阶段
# - 本示例仅关注前者情况，后者情况可以自行添加eol_calculator
# - 前半部分 XJTU数据集
# - 后半部分 PHM2012数据集

# %%
from rulframework.data.FeatureExtractor import FeatureExtractor
from rulframework.data.loader.bearing.XJTULoader import XJTULoader
from rulframework.data.loader.bearing.PHM2012Loader import PHM2012Loader
from rulframework.data.processor.RMSProcessor import RMSProcessor
from rulframework.data.stage.BearingStageCalculator import BearingStageCalculator
from rulframework.data.stage.eol.NinetyThreePercentRMSEoLCalculator import NinetyThreePercentRMSEoLCalculator
from rulframework.data.stage.fpt.ThreeSigmaFPTCalculator import ThreeSigmaFPTCalculator
from rulframework.util.Plotter import Plotter

# %% [markdown]
# ## 设置轴承全寿命阶段划分算法
# - FPT使用3σ算法

# %%
Plotter.DPI = 80 # 降低图片分辨率防止notebook卡顿
fpt_calculator = ThreeSigmaFPTCalculator()

# %% [markdown]
# ## ⭐ 生成XJTU数据集所有轴承特征图

# %%
data_loader = XJTULoader('D:\\data\\dataset\\XJTU-SY_Bearing_Datasets')
# Out:
# DEBUG - 17:48:03 >>
# << Root directory of dataset: D:\data\dataset\XJTU-SY_Bearing_Datasets
# 	Bearing1_1, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\35Hz12kN\Bearing1_1
# 	Bearing1_2, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\35Hz12kN\Bearing1_2
# 	Bearing1_3, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\35Hz12kN\Bearing1_3
# 	Bearing1_4, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\35Hz12kN\Bearing1_4
# 	Bearing1_5, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\35Hz12kN\Bearing1_5
# 	Bearing2_1, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\37.5Hz11kN\Bearing2_1
# 	Bearing2_2, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\37.5Hz11kN\Bearing2_2
# 	Bearing2_3, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\37.5Hz11kN\Bearing2_3
# 	Bearing2_4, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\37.5Hz11kN\Bearing2_4
# 	Bearing2_5, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\37.5Hz11kN\Bearing2_5
# 	Bearing3_1, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\40Hz10kN\Bearing3_1
# 	Bearing3_2, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\40Hz10kN\Bearing3_2
# 	Bearing3_3, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\40Hz10kN\Bearing3_3
# 	Bearing3_4, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\40Hz10kN\Bearing3_4
# 	Bearing3_5, location: D:\data\dataset\XJTU-SY_Bearing_Datasets\40Hz10kN\Bearing3_5

# %%
feature_extractor = FeatureExtractor(RMSProcessor(data_loader.continuum))
stage_calculator = BearingStageCalculator(data_loader.continuum, fpt_calculator)

# %%
def plot(name):
    bearing = data_loader(name, columns='Horizontal Vibration')
    feature_extractor(bearing)
    stage_calculator(bearing)
    Plotter.feature(bearing)

# %% [markdown]
# #### 使用循环一次性输出所有特征图
# 此处因为图片太多notebook会自动压缩格子，导致不方便查看
# 所以注释代码，实际使用建议用循环

# %%
# for bearing_name in data_loader.all:
#     bearing = data_loader.get_bearing(bearing_name, columns='Horizontal Vibration')
#     feature_extractor.extract(bearing)
#     stage_calculator.calculate_state(bearing)
#     bearing.plot_feature()

# %%
plot("Bearing1_1")
# Out:
# INFO - 17:48:03 >> Loading data entity: Bearing1_1
# INFO - 17:48:05 >> Successfully loaded data entity: Bearing1_1

# %%
plot("Bearing1_2")
# Out:
# INFO - 17:48:06 >> Loading data entity: Bearing1_2
# INFO - 17:48:09 >> Successfully loaded data entity: Bearing1_2

# %%
plot("Bearing1_3")
# Out:
# INFO - 17:48:09 >> Loading data entity: Bearing1_3
# INFO - 17:48:12 >> Successfully loaded data entity: Bearing1_3

# %%
plot("Bearing1_4")
# Out:
# INFO - 17:48:13 >> Loading data entity: Bearing1_4
# INFO - 17:48:15 >> Successfully loaded data entity: Bearing1_4

# %%
plot("Bearing1_5")
# Out:
# INFO - 17:48:15 >> Loading data entity: Bearing1_5
# INFO - 17:48:16 >> Successfully loaded data entity: Bearing1_5

# %%
plot("Bearing2_1")
# Out:
# INFO - 17:48:16 >> Loading data entity: Bearing2_1
# INFO - 17:48:26 >> Successfully loaded data entity: Bearing2_1

# %%
plot("Bearing2_2")
# Out:
# INFO - 17:48:26 >> Loading data entity: Bearing2_2
# INFO - 17:48:29 >> Successfully loaded data entity: Bearing2_2

# %%
plot("Bearing2_3")
# Out:
# INFO - 17:48:29 >> Loading data entity: Bearing2_3
# INFO - 17:48:39 >> Successfully loaded data entity: Bearing2_3

# %%
plot("Bearing2_4")
# Out:
# INFO - 17:48:39 >> Loading data entity: Bearing2_4
# INFO - 17:48:40 >> Successfully loaded data entity: Bearing2_4

# %%
plot("Bearing2_5")
# Out:
# INFO - 17:48:40 >> Loading data entity: Bearing2_5
# INFO - 17:48:46 >> Successfully loaded data entity: Bearing2_5

# %%
plot("Bearing3_1")
# Out:
# INFO - 17:48:46 >> Loading data entity: Bearing3_1
# INFO - 17:49:33 >> Successfully loaded data entity: Bearing3_1

# %%
plot("Bearing3_2")
# Out:
# INFO - 17:49:34 >> Loading data entity: Bearing3_2
# INFO - 17:50:20 >> Successfully loaded data entity: Bearing3_2

# %%
plot("Bearing3_3")
# Out:
# INFO - 17:50:20 >> Loading data entity: Bearing3_3
# INFO - 17:50:27 >> Successfully loaded data entity: Bearing3_3

# %%
plot("Bearing3_4")
# Out:
# INFO - 17:50:27 >> Loading data entity: Bearing3_4
# INFO - 17:50:56 >> Successfully loaded data entity: Bearing3_4

# %%
plot("Bearing3_5")
# Out:
# INFO - 17:50:57 >> Loading data entity: Bearing3_5
# INFO - 17:50:59 >> Successfully loaded data entity: Bearing3_5

# %% [markdown]
# ## ⭐ 生成PHM数据集所有轴承特征图

# %%
data_loader = PHM2012Loader('D:\\data\\dataset\\phm-ieee-2012-data-challenge-dataset-master')
feature_extractor.continuum = data_loader.continuum
stage_calculator.scale = data_loader.continuum
# Out:
# DEBUG - 17:50:59 >>
# << Root directory of dataset: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master
# 	Bearing1_1, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Learning_set\Bearing1_1
# 	Bearing1_2, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Learning_set\Bearing1_2
# 	Bearing2_1, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Learning_set\Bearing2_1
# 	Bearing2_2, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Learning_set\Bearing2_2
# 	Bearing3_1, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Learning_set\Bearing3_1
# 	Bearing3_2, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Learning_set\Bearing3_2
# 	Bearing1_3, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing1_3
# 	Bearing1_4, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing1_4
# 	Bearing1_5, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing1_5
# 	Bearing1_6, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing1_6
# 	Bearing1_7, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing1_7
# 	Bearing2_3, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing2_3
# 	Bearing2_4, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing2_4
# 	Bearing2_5, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing2_5
# 	Bearing2_6, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing2_6
# 	Bearing2_7, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing2_7
# 	Bearing3_3, location: D:\data\dataset\phm-ieee-2012-data-challenge-dataset-master\Full_Test_Set\Bearing3_3

# %%
plot("Bearing1_1")
# Out:
# INFO - 17:50:59 >> Loading data entity: Bearing1_1
# INFO - 17:51:06 >> Successfully loaded data entity: Bearing1_1

# %%
plot("Bearing1_2")
# Out:
# INFO - 17:51:06 >> Loading data entity: Bearing1_2
# INFO - 17:51:08 >> Successfully loaded data entity: Bearing1_2

# %%
plot("Bearing1_3")
# Out:
# INFO - 17:51:08 >> Loading data entity: Bearing1_3
# INFO - 17:51:15 >> Successfully loaded data entity: Bearing1_3

# %%
plot("Bearing1_4")
# Out:
# INFO - 17:51:15 >> Loading data entity: Bearing1_4
# INFO - 17:51:19 >> Successfully loaded data entity: Bearing1_4

# %%
plot("Bearing1_5")
# Out:
# INFO - 17:51:19 >> Loading data entity: Bearing1_5
# INFO - 17:51:26 >> Successfully loaded data entity: Bearing1_5

# %%
plot("Bearing1_6")
# Out:
# INFO - 17:51:26 >> Loading data entity: Bearing1_6
# INFO - 17:51:33 >> Successfully loaded data entity: Bearing1_6

# %%
plot("Bearing1_7")
# Out:
# INFO - 17:51:33 >> Loading data entity: Bearing1_7
# INFO - 17:51:39 >> Successfully loaded data entity: Bearing1_7

# %%
plot("Bearing2_1")
# Out:
# INFO - 17:51:39 >> Loading data entity: Bearing2_1
# INFO - 17:51:42 >> Successfully loaded data entity: Bearing2_1

# %%
plot("Bearing2_2")
# Out:
# INFO - 17:51:42 >> Loading data entity: Bearing2_2
# INFO - 17:51:44 >> Successfully loaded data entity: Bearing2_2

# %%
plot("Bearing2_3")
# Out:
# INFO - 17:51:44 >> Loading data entity: Bearing2_3
# INFO - 17:51:50 >> Successfully loaded data entity: Bearing2_3
# WARNING - 17:51:50 >> fail to identify FPT, used default value 0

# %%
plot("Bearing2_4")
# Out:
# INFO - 17:51:50 >> Loading data entity: Bearing2_4
# INFO - 17:51:52 >> Successfully loaded data entity: Bearing2_4
# WARNING - 17:51:52 >> fail to identify FPT, used default value 0

# %%
plot("Bearing2_5")
# Out:
# INFO - 17:51:52 >> Loading data entity: Bearing2_5
# INFO - 17:51:58 >> Successfully loaded data entity: Bearing2_5
# WARNING - 17:51:58 >> fail to identify FPT, used default value 0

# %%
plot("Bearing2_6")
# Out:
# INFO - 17:51:59 >> Loading data entity: Bearing2_6
# INFO - 17:52:01 >> Successfully loaded data entity: Bearing2_6

# %%
plot("Bearing2_7")
# Out:
# INFO - 17:52:01 >> Loading data entity: Bearing2_7
# INFO - 17:52:01 >> Successfully loaded data entity: Bearing2_7
# WARNING - 17:52:01 >> fail to identify FPT, used default value 0

# %%
plot("Bearing3_1")
# Out:
# INFO - 17:52:02 >> Loading data entity: Bearing3_1
# INFO - 17:52:03 >> Successfully loaded data entity: Bearing3_1

# %%
plot("Bearing3_2")
# Out:
# INFO - 17:52:03 >> Loading data entity: Bearing3_2
# INFO - 17:52:07 >> Successfully loaded data entity: Bearing3_2

# %%
plot("Bearing3_3")
# Out:
# INFO - 17:52:07 >> Loading data entity: Bearing3_3
# INFO - 17:52:09 >> Successfully loaded data entity: Bearing3_3
